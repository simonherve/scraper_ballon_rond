# %%
import pickle
dico = {"Angleterre":
            {   
                "region": 252,
                "Premier League":
                    {
                        "tournament": 2,
                        "2021/2022": 8618,
                        "2020/2021": 8228,
                        "2019/2020": 7811,
                        "2018/2019": 7361,
                        "2017/2018": 6829,
                        "2016/2017": 6335,
                        "2015/2016": 5826,
                        "2014/2015": 4311,
                        "2013/2014": 3853,
                        "2012/2013": 3389,
                        "2011/2012": 2935,
                        "2010/2011": 2458,
                        "2009/2010": 1849
                    },
                "Championship": 
                    {
                        "tournament": 7,
                        "2021/2022": -1,
                        "2020/2021": -1,
                        "2019/2020": -1,
                        "2018/2019": -1,
                        "2017/2018": -1,
                        "2016/2017": -1,
                        "2015/2016": -1,
                        "2014/2015": -1,
                        "2013/2014": -1,
                        "2012/2013": -1,
                        "2011/2012": -1,
                        "2010/2011": -1,
                        "2009/2010": -1,
                    },
                "League One": 
                    {
                        "tournament": 8,
                        "2021/2022": -1,
                        "2020/2021": -1,
                        "2019/2020": -1,
                        "2018/2019": -1,
                        "2017/2018": -1,
                        "2016/2017": -1,
                        "2015/2016": -1,
                        "2014/2015": -1,
                        "2013/2014": -1,
                        "2012/2013": -1,
                        "2011/2012": -1,
                        "2010/2011": -1,
                        "2009/2010": -1,
                    },
                "League Two": 
                    {
                        "tournament": 9,
                        "2021/2022": -1,
                        "2020/2021": -1,
                        "2019/2020": -1,
                        "2018/2019": -1,
                        "2017/2018": -1,
                        "2016/2017": -1,
                        "2015/2016": -1,
                        "2014/2015": -1,
                        "2013/2014": -1,
                        "2012/2013": -1,
                        "2011/2012": -1,
                        "2010/2011": -1,
                        "2009/2010": -1,
                    }
            },
        "Italie": 
            {
                "region": 108,
                "Serie A": 
                    {
                        "tournament": 5,
                        "2021/2022": 8735,
                        "2020/2021": 8330,
                        "2019/2020": 7928,
                        "2018/2019": 7468,
                        "2017/2018": 6974,
                        "2016/2017": 6461,
                        "2015/2016": 5970,
                        "2014/2015": 5441,
                        "2013/2014": 3978,
                        "2012/2013": 3512,
                        "2011/2012": 3054,
                        "2010/2011": 2626,
                        "2009/2010": 1957
                    }
            },
        "Espagne": 
            {
                "region": 206,
                "LaLiga": 
                    {
                        "tournament": 4,
                        "2021/2022": 8681,
                        "2020/2021": 8321,
                        "2019/2020": 7889,
                        "2018/2019": 7466,
                        "2017/2018": 6960,
                        "2016/2017": 6436,
                        "2015/2016": 5933,
                        "2014/2015": 5435,
                        "2013/2014": 3922,
                        "2012/2013": 3470,
                        "2011/2012": 3004,
                        "2010/2011": 2596,
                        "2009/2010": 1929
                    }
            },
        "Allemagne": 
            {
                "region": 81,
                "Bundesliga": 
                    {
                        "tournament": 3,
                        "2021/2022": 8667,
                        "2020/2021": 8279,
                        "2019/2020": 7872,
                        "2018/2019": 7405,
                        "2017/2018": 6902,
                        "2016/2017": 6392,
                        "2015/2016": 5870,
                        "2014/2015": 4336,
                        "2013/2014": 3863,
                        "2012/2013": 3424,
                        "2011/2012": 2949,
                        "2010/2011": 2520,
                        "2009/2010": 1903
                    },
                "Bundesliga II": 
                    {
                        "tournament": 6,
                        "2021/2022": 8668,
                        "2020/2021": 8280,
                        "2019/2020": 7873,
                        "2018/2019": 7406,
                        "2017/2018": 6903,
                        "2016/2017": 6393,
                        "2015/2016": 5871     
                    }
            },
        "France": 
            {
                "region": 74,
                "Ligue 1": 
                    {
                        "tournament": 22,
                        "2021/2022": 8671,
                        "2020/2021": 8185,
                        "2019/2020": 7814,
                        "2018/2019": 7344,
                        "2017/2018": 6833,
                        "2016/2017": 6318,
                        "2015/2016": 5830,
                        "2014/2015": 4279,
                        "2013/2014": 3836,
                        "2012/2013": 3356,
                        "2011/2012": 2920,
                        "2010/2011": 2417,
                        "2009/2010": 1839
                    }
                    
            },
        "Portugal": 
            {
                "region": 177,
                "Liga NOS": 
                    {
                        "tournament": 21,
                        "2021/2022": 8714,
                        "2020/2021": 8315,
                        "2019/2020": 7893,
                        "2018/2019": 7429,
                        "2017/2018": 6933,
                        "2016/2017": 6438
                    }
            },
        "Pays Bas": 
            {
                "region": 155,
                "Eredivisie": 
                    {
                        "tournament": 13,
                        "2021/2022": -1,
                        "2020/2021": -1,
                        "2019/2020": -1,
                        "2018/2019": -1,
                        "2017/2018": -1,
                        "2016/2017": -1,
                        "2015/2016": -1,
                        "2014/2015": -1,
                        "2013/2014": -1,
                        "2012/2013": -1,
                        "2011/2012": -1,
                        "2010/2011": -1,
                        "2009/2010": -1,
                    }
            },
        "Russie":
            {
                "region": 182,
                "Premier League": 
                    {
                        "tournament": 77,
                        "2021/2022": 8639,
                        "2020/2021": 8242,
                        "2019/2020": 7802,
                        "2018/2019": 7389,
                        "2017/2018": 6819,
                        "2016/2017": 6357,
                        "2015/2016": 5859,
                        "2014/2015": 4303,
                        "2013/2014": 3861
                    }
            },
        "Brésil": 
            {
                "region": 31,
                "Brasileirão": 
                    {
                        "tournament": 95,
                        "2021/2022": 8555,
                        "2020/2021": 8158,
                        "2019/2020": 7683,
                        "2018/2019": 7243,
                        "2017/2018": 6700,
                        "2016/2017": 6242,
                        "2015/2016": 5713,
                        "2014/2015": 4185,
                        "2013/2014": 3753
                    }
            },
        "USA":
            {
                "region": 233,
                "Major League Soccer": 
                    {
                        "tournament": 85,
                        "2021/2022": 
                            {
                                "season":-1,
                                "regular":-1,
                                "playoff":-1
                            },
                        "2020/2021":
                            {
                                "season":-1,
                                "regular":-1,
                                "playoff":-1
                            },
                        "2019/2020":
                            {
                                "season":-1,
                                "regular":-1,
                                "playoff":-1
                            },
                        "2018/2019":
                            {
                                "season":-1,
                                "regular":-1,
                                "playoff":-1
                            },
                        "2017/2018":
                            {
                                "season":-1,
                                "regular":-1,
                                "playoff":-1
                            },
                        "2016/2017":
                            {
                                "season":-1,
                                "regular":-1,
                                "playoff":-1
                            },
                        "2015/2016":
                            {
                                "season":-1,
                                "regular":-1,
                                "playoff":-1
                            },
                        "2014/2015":
                            {
                                "season":-1,
                                "regular":-1,
                                "playoff":-1
                            },
                        "2013/2014": 
                            { 
                                "season":3672,
                                "regular":-1,
                                "playoff":-1 
                            }
                    }
            },
         "Turquie": 
            {
                "region": 225,
                "Super Lig": 
                    {
                        "tournament": 17,
                        "2021/2022": 8732,
                        "2020/2021": 8313,
                        "2019/2020": 7912,
                        "2018/2019": 7437,
                        "2017/2018": 6936,
                        "2016/2017": 6447,
                        "2015/2016": 5915,
                        "2014/2015": 5411
                    }
            },
        "Écosse": 
            {
                "region": 253,
                "Premiership": 
                    {
                        "tournament": 20,
                        "2021/2022": 8636,
                        "2020/2021": 8191
                    }
            },
        "Argentine":
            {
                "region": 11,
                "Liga Profesional": 
                    {
                        "tournament": 68,
                        "2021/2022": -1,
                        "2020/2021": -1,
                        "2019/2020": -1,
                        "2018/2019": -1,
                        "2017/2018": -1,
                        "2016/2017": -1,
                        "2015/2016": -1,
                        "2014/2015": -1,
                        "2013/2014": -1,
                        "2012/2013": -1,
                        "2011/2012": -1,
                        "2010/2011": -1,
                        "2009/2010": -1,
                    }
            },
        "Belgique":
            {
                "region": 22,
                "Jupiler Pro League": 
                    {
                        "tournament": 18,
                        "2021/2022": -1,
                        "2020/2021": -1,
                        "2019/2020": -1,
                        "2018/2019": -1,
                        "2017/2018": -1,
                        "2016/2017": -1,
                        "2015/2016": -1,
                        "2014/2015": -1,
                        "2013/2014": -1,
                        "2012/2013": -1,
                        "2011/2012": -1,
                        "2010/2011": -1,
                        "2009/2010": -1,
                    }
            },
        "Europe": 
            {
                "region": 250,
                "Champions League": 
                    {
                        "tournament": 12,
                        "2021/2022": -1,
                        "2020/2021": -1,
                        "2019/2020": -1,
                        "2018/2019": -1,
                        "2017/2018": -1,
                        "2016/2017": -1,
                        "2015/2016": -1,
                        "2014/2015": -1,
                        "2013/2014": -1,
                        "2012/2013": -1,
                        "2011/2012": -1,
                        "2010/2011": -1,
                        "2009/2010": -1,
                    },
                "Europa League": 
                    {
                        "tournament": 30,
                        "2021/2022": -1,
                        "2020/2021": -1,
                        "2019/2020": -1,
                        "2018/2019": -1,
                        "2017/2018": -1,
                        "2016/2017": -1,
                        "2015/2016": -1,
                        "2014/2015": -1,
                        "2013/2014": -1,
                        "2012/2013": -1,
                        "2011/2012": -1,
                        "2010/2011": -1,
                        "2009/2010": -1,
                    }
            }
       }

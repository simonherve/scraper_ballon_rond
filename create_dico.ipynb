# %%
import pickle
dico = {"Angleterre":
            {   
                "region": 252,
                "Premier League":
                    {
                        "tournament": 2,
                        "2021/2022": 8618,
                        "2020/2021": 8228,
                        "2019/2020": 7811,
                        "2018/2019": 7361,
                        "2017/2018": 6829,
                        "2016/2017": 6335,
                        "2015/2016": 5826,
                        "2014/2015": 4311,
                        "2013/2014": 3853,
                        "2012/2013": 3389,
                        "2011/2012": 2935,
                        "2010/2011": 2458,
                        "2009/2010": 1849
                    },
                "Championship": 
                    {
                        "tournament": 7,
                        "2021/2022":
                            {
                                "season": 8619,
                                "regular": -1,
                                "playoff": -1
                            },
                        "2020/2021":
                            {
                                "season": 8304,
                                "regular": 18825,
                                "playoff":19661
                            },
                        "2019/2020":
                            {
                                "season": 7840,
                                "regular": 17629,
                                "playoff": 18673
                            },
                        "2018/2019": 
                            {
                                "season": 7379,
                                "regular": 16389,
                                "playoff": 17369
                            },
                        "2017/2018": 
                            {
                                "season": 6848,
                                "regular": 15177,
                                "playoff": 16231
                            },
                        "2016/2017": 
                            {
                                "season": 6365,
                                "regular": 13832,
                                "playoff": 14976
                            },
                        "2015/2016": 
                            {
                                "season": 5827,
                                "regular": 12497,
                                "playoff": 13644
                            },
                        "2014/2015": 
                            {
                                "season": 4312,
                                "regular": 9156,
                                "playoff": 12309
                            },
                        "2013/2014": 
                            {
                                "season": 3859,
                                "regular": 7800,
                                "playoff":9012
                            }
                    },
                "League One": 
                    {
                        "tournament": 8,
                        "2021/2022": 
                            {
                                "season": 8620,
                                "regular": -1,
                                "playoff": -1
                            },
                        "2020/2021": 
                            {
                                "season": 8305,
                                "regular": 18826,
                                "playoff": 19705
                            },
                        "2019/2020": 
                            {
                                "season": 7841,
                                "regular": 17630,
                                "playoff": 18549
                            },
                        "2018/2019": 
                            {
                                "season": 7380,
                                "regular": 16390,
                                "playoff": 16391 
                            }
                    },
                "League Two": 
                    {
                        "tournament": 9,
                        "2021/2022":
                            {
                                "season": 8621,
                                "regular": -1,
                                "playoff": -1
                            },
                        "2020/2021":
                            {
                                "season": 8306,
                                "regular": 18827,
                                "playoff": 19704
                            },
                        "2019/2020":
                            {
                                "season": 7842,
                                "regular": 17631,
                                "playoff": 18538
                            },
                        "2018/2019": 
                            {
                                "season": 7381,
                                "regular": 16392,
                                "playoff": 17396
                            }
                    }
            },
        "Italie": 
            {
                "region": 108,
                "Serie A": 
                    {
                        "tournament": 5,
                        "2021/2022": 8735,
                        "2020/2021": 8330,
                        "2019/2020": 7928,
                        "2018/2019": 7468,
                        "2017/2018": 6974,
                        "2016/2017": 6461,
                        "2015/2016": 5970,
                        "2014/2015": 5441,
                        "2013/2014": 3978,
                        "2012/2013": 3512,
                        "2011/2012": 3054,
                        "2010/2011": 2626,
                        "2009/2010": 1957
                    }
            },
        "Espagne": 
            {
                "region": 206,
                "LaLiga": 
                    {
                        "tournament": 4,
                        "2021/2022": 8681,
                        "2020/2021": 8321,
                        "2019/2020": 7889,
                        "2018/2019": 7466,
                        "2017/2018": 6960,
                        "2016/2017": 6436,
                        "2015/2016": 5933,
                        "2014/2015": 5435,
                        "2013/2014": 3922,
                        "2012/2013": 3470,
                        "2011/2012": 3004,
                        "2010/2011": 2596,
                        "2009/2010": 1929
                    }
            },
        "Allemagne": 
            {
                "region": 81,
                "Bundesliga": 
                    {
                        "tournament": 3,
                        "2021/2022": 8667,
                        "2020/2021": 8279,
                        "2019/2020": 7872,
                        "2018/2019": 7405,
                        "2017/2018": 6902,
                        "2016/2017": 6392,
                        "2015/2016": 5870,
                        "2014/2015": 4336,
                        "2013/2014": 3863,
                        "2012/2013": 3424,
                        "2011/2012": 2949,
                        "2010/2011": 2520,
                        "2009/2010": 1903
                    },
                "Bundesliga II": 
                    {
                        "tournament": 6,
                        "2021/2022": 8668,
                        "2020/2021": 8280,
                        "2019/2020": 7873,
                        "2018/2019": 7406,
                        "2017/2018": 6903,
                        "2016/2017": 6393,
                        "2015/2016": 5871     
                    }
            },
        "France": 
            {
                "region": 74,
                "Ligue 1": 
                    {
                        "tournament": 22,
                        "2021/2022": 8671,
                        "2020/2021": 8185,
                        "2019/2020": 7814,
                        "2018/2019": 7344,
                        "2017/2018": 6833,
                        "2016/2017": 6318,
                        "2015/2016": 5830,
                        "2014/2015": 4279,
                        "2013/2014": 3836,
                        "2012/2013": 3356,
                        "2011/2012": 2920,
                        "2010/2011": 2417,
                        "2009/2010": 1839
                    }
                    
            },
        "Portugal": 
            {
                "region": 177,
                "Liga NOS": 
                    {
                        "tournament": 21,
                        "2021/2022": 8714,
                        "2020/2021": 8315,
                        "2019/2020": 7893,
                        "2018/2019": 7429,
                        "2017/2018": 6933,
                        "2016/2017": 6438
                    }
            },
        "Pays Bas": 
            {
                "region": 155,
                "Eredivisie": 
                    {
                        "tournament": 13,
                        "2021/2022": 
                            {
                                "season": 8625,
                                "regular": -1,
                                "playoff": -1
                            },
                        "2020/2021": 
                            {
                                "season": 8187,
                                "regular": 18596,
                                "playoff": 19720
                            },
                        "2019/2020": 
                            {
                                "season": 7815,
                                "regular": -1,
                                "playoff": -1
                            },
                        "2018/2019": 
                            {
                                "season": 7354,
                                "regular": 16360,
                                "playoff": 17382
                            },
                        "2017/2018": 
                            {
                                "season": 6826,
                                "regular": 15148,
                                "playoff": 16192
                            },
                        "2016/2017":
                            {
                                "season": 6331,
                                "regular": 13792,
                                "playoff": 15035
                            },
                        "2015/2016":
                            {
                                "season": 5810,
                                "regular": 12467,
                                "playoff": 13622
                            },
                        "2014/2015":
                            {
                                "season": 4289,
                                "regular": 9121,
                                "playoff": 12386
                            },
                        "2013/2014":
                            {
                                "season": 3851,
                                "regular": 7790,
                                "playoff": 9026
                            }
                    }
            },
        "Russie":
            {
                "region": 182,
                "Premier League": 
                    {
                        "tournament": 77,
                        "2021/2022": 8639,
                        "2020/2021": 8242,
                        "2019/2020": 7802,
                        "2018/2019": 7389,
                        "2017/2018": 6819,
                        "2016/2017": 6357,
                        "2015/2016": 5859,
                        "2014/2015": 4303,
                        "2013/2014": 3861
                    }
            },
        "Brésil": 
            {
                "region": 31,
                "Brasileirão": 
                    {
                        "tournament": 95,
                        "2021/2022": 8555,
                        "2020/2021": 8158,
                        "2019/2020": 7683,
                        "2018/2019": 7243,
                        "2017/2018": 6700,
                        "2016/2017": 6242,
                        "2015/2016": 5713,
                        "2014/2015": 4185,
                        "2013/2014": 3753
                    }
            },
        "USA":
            {
                "region": 233,
                "Major League Soccer": 
                    {
                        "tournament": 85,
                        "2021/2022": 
                            {
                                "season": 8545,
                                "regular": 19513,
                                "playoff": 20272
                            },
                        "2020/2021":
                            {
                                "season": 8055,
                                "regular": 18171,
                                "playoff": 19087,
                                "champlayoff": 18547,
                                "groupstage": 18592,
                                "groupA": 18541,
                                "groupB": 18542,
                                "groupC": 18543,
                                "groupD": 18544,
                                "groupE": 18545,
                                "groupF": 18546
                            },
                        "2019/2020":
                            {
                                "season": 7609,
                                "regular": 17011,
                                "playoff": 18006
                            },
                        "2018/2019":
                            {
                                "season": 7172,
                                "regular": 15823,
                                "playoff": 16768
                            },
                        "2017/2018":
                            {
                                "season": 6620,
                                "regular": 14550,
                                "playoff": 15593 
                            },
                        "2016/2017":
                            {
                                "season": 6137,
                                "regular": 13276,
                                "playoff": 14288
                            },
                        "2015/2016":
                            {
                                "season": 5607,
                                "regular": 11890,
                                "playoff": 12994
                            },
                        "2014/2015":
                            {
                                "season": 4091,
                                "regular": 8358,
                                "playoff": 11611
                            },
                        "2013/2014": 
                            { 
                                "season":3672,
                                "regular": 7250,
                                "playoff": 8275
                            }
                    }
            },
         "Turquie": 
            {
                "region": 225,
                "Super Lig": 
                    {
                        "tournament": 17,
                        "2021/2022": 8732,
                        "2020/2021": 8313,
                        "2019/2020": 7912,
                        "2018/2019": 7437,
                        "2017/2018": 6936,
                        "2016/2017": 6447,
                        "2015/2016": 5915,
                        "2014/2015": 5411
                    }
            },
        "Écosse": 
            {
                "region": 253,
                "Premiership": 
                    {
                        "tournament": 20,
                        "2021/2022": 8636,
                        "2020/2021": 8191
                    }
            },
        "Argentine":
            {
                "region": 11,
                "Liga Profesional": 
                    {
                        "tournament": 68,
                        "2021/2022": 20272,
                        "2020/2021": -1,
                        "2019/2020": 20272,
                        "2018/2019": 7460,
                        "2017/2018": 6995,
                        "2016/2017": 6484
                    }
            },
        "Belgique":
            {
                "region": 22,
                "Jupiler Pro League": 
                    {
                        "tournament": 18,
                        "2021/2022": 8627,
                        "2020/2021": 
                            {
                                "season": 8197,
                                "regular": 18620,
                                "group": 19625,
                                "playoff": 19624
                            }
                    }
            },
        "Europe": 
            {
                "region": 250,
                "Champions League": 
                    {
                        "tournament": 12,
                        "2021/2022":
                            {
                                "season": 8623,
                                "group": 20149,
                                "final": -1
                            },
                        "2020/2021":
                            {
                                "season": 8177,
                                "group": 19009,
                                "final": 19130
                            },
                        "2019/2020":
                            {
                                "season": 7804,
                                "group": 17993,
                                "final": 18065
                            },
                        "2018/2019":
                            {
                                "season": 7352,
                                "group": 16704,
                                "final": 16651
                            },
                        "2017/2018": 
                            {
                                "season": 6842,
                                "group": 15511,
                                "final": 15619
                            },
                        "2016/2017": 
                            {
                                "season": 6349,
                                "group": 14201,
                                "final": 14361
                            },
                        "2015/2016": 
                            {
                                "season": 5848,
                                "group": 12933,
                                "final": 13185
                            },
                        "2014/2015": 
                            {
                                "season": 4333,
                                "group": 11564,
                                "final": 11810
                            },
                        "2013/2014": 
                            {
                                "season": 3872,
                                "group": 8175,
                                "final": 8462
                            },
                        "2012/2013": 
                            {
                                "season": 3416,
                                "group": 6885,
                                "final": 7228
                            },
                        "2011/2012": 
                            {
                                "season": 2944,
                                "group": 6223,
                                "final": 6021
                            },
                        "2010/2011":
                            {
                                "season": 2474,
                                "group": 6222,
                                "final": 5021
                            },
                        "2009/2010":
                            {
                                "season": 1868,
                                "group": 6219,
                                "final": 3571
                            },
                    },
                "Europa League": 
                    {
                        "tournament": 30,
                        "2021/2022": 
                            {
                                "season": 8741,
                                "group": 20148,
                                "final": -1
                            },
                        "2020/2021": 
                            {
                                "season": 8178,
                                "group": 19010,
                                "final": -1 
                            },
                        "2019/2020": 
                            {
                                "season": 7805,
                                "group": 17994,
                                "final": 18066
                            },
                        "2018/2019": 
                            {
                                "season": 7353,
                                "group": 16705,
                                "final": 16786
                            },
                        "2017/2018": 
                            {
                                "season": 6843,
                                "group": 15512,
                                "final": 15617
                            },
                        "2016/2017": 
                            {
                                "season": 6275,
                                "group": 14202,
                                "final": 14368
                            },
                        "2015/2016": 
                            {
                                "season": 5849,
                                "group": 12934,
                                "final": 13186
                            },
                        "2014/2015": 
                            {
                                "season": 4332,
                                "group": 11565,
                                "final": 11811
                            },
                        "2013/2014": 
                            {
                                "season": 3871,
                                "group": 8209,
                                "final": 8466
                            },
                        "2012/2013": 
                            {
                                "season": 3418,
                                "group": 6913,
                                "final": 7229
                            }
                    }
            }
       }   

with open("dico.pkl", "wb") as f:
    pickle.dump(dico, f)
